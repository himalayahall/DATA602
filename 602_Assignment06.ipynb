# %% [markdown]
# <a href="https://colab.research.google.com/github/himalayahall/DATA602/blob/main/602_Assignment06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
datasets = {'https://raw.githubusercontent.com/data602sps/datasetspractice/main/salarydata.csv' : None,
            'https://raw.githubusercontent.com/data602sps/datasetspractice/main/kobe.csv' : None,

            # Datasets from https://catalog.data.gov/dataset uploaded into Github
            'https://raw.githubusercontent.com/himalayahall/DATA602/main/Lottery_Powerball_Winning_Numbers__Beginning_2010.csv':  None,
            'https://raw.githubusercontent.com/himalayahall/DATA602/main/Demographic_Statistics_By_Zip_Code.csv' : None
            
            }

# %% [markdown]
# # Q1
#
# Load your dataset into python using the pandas library and save data into a
# dataframe named dfi (where i is one of your datasets, for a total of 4)

# %%
for item in datasets.items():
  datasets[item[0]] = pd.read_csv(item[0])

# %% [markdown]
# # Q2
#
# Preview your data by calling your dataframe’s name. How many columns and rows
# do you see?
#
# 1. salarydata.csv - 51 rows x  3 columns (3rd column is junk)
# 2. kobe.csv - 133 rows x 6 columns
# 3. Lottery_Powerball_Winning_Numbers__Beginning_2010 - 1439 rows x 3 columns
# 4. Demographic_Statistics_By_Zip_Code.csv - 236 rows x 46 columns

# %%
for item in datasets.items():
  print(datasets[item[0]])
# Out:
#                    Sate  2018 Mean Annual Wage  Unnamed: 2
# 0               Alabama                 90,620         NaN
# 1                 Alaska                99,180         NaN
# 2                Arizona                88,800         NaN
# 3               Arkansas                81,430         NaN
# 4             California                97,110         NaN
# 5               Colorado                82,560         NaN
# 6            Connecticut                96,010         NaN
# 7               Delaware                93,880         NaN
# 8   District of Columbia                89,880         NaN
# 9                Florida                87,410         NaN
# 10               Georgia                86,320         NaN
# 11                Hawaii                90,540         NaN
# 12                 Idaho                77,700         NaN
# 13              IIIinois                90,690         NaN
# 14               lndiana                83,680         NaN
# ...

# %% [markdown]
# # Q3
#
# Examine the shape of your data using the .shape command and the data types of
# your columns using .dtypes.

# %%
for item in datasets.items():
  df = pd.DataFrame(item[1])
  print(f'{item[0]}: shape: {df.shape}\n{df.dtypes}')
# Out:
# https://raw.githubusercontent.com/data602sps/datasetspractice/main/salarydata.csv: shape: (51, 3)
# Sate                      object
# 2018 Mean Annual Wage     object
# Unnamed: 2               float64
# dtype: object
# https://raw.githubusercontent.com/data602sps/datasetspractice/main/kobe.csv: shape: (133, 6)
# vs             object
# game            int64
# quarter        object
# time           object
# description    object
# basket         object
# dtype: object
# https://raw.githubusercontent.com/himalayahall/DATA602/main/Lottery_Powerball_Winning_Numbers__Beginning_2010.csv: shape: (1439, 3)
# Draw Date           object
# Winning Numbers     object
# Multiplier         float64
# dtype: object
# https://raw.githubusercontent.com/himalayahall/DATA602/main/Demographic_Statistics_By_Zip_Code.csv: shape: (236, 46)
# JURISDICTION NAME                        int64
# COUNT PARTICIPANTS                       int64
# COUNT FEMALE                             int64
# ...

# %% [markdown]
# # Q4
#
# Use .describe() on your data. What do you notice about your data? What does this command return?
#
# .describe() returns summary statistics about numeric columns in the dataset. I notice that some columns containing numeric data had dtype object and are ignored by .describe()

# %%
df = datasets['https://raw.githubusercontent.com/data602sps/datasetspractice/main/salarydata.csv']
df.dtypes
# Out:
# Sate                      object
# 2018 Mean Annual Wage     object
# Unnamed: 2               float64
# dtype: object

# %%
for item in datasets.items():
  df = pd.DataFrame(item[1])
  print(f'{item[0]}: {df.describe()}')
# Out:
# https://raw.githubusercontent.com/data602sps/datasetspractice/main/salarydata.csv:        Unnamed: 2
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN
# https://raw.githubusercontent.com/data602sps/datasetspractice/main/kobe.csv:              game
# count  133.000000
# mean     2.902256
# std      1.450521
# min      1.000000
# 25%      1.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000
# https://raw.githubusercontent.com/himalayahall/DATA602/main/Lottery_Powerball_Winning_Numbers__Beginning_2010.csv:         Multiplier
# count  1229.000000
# mean      2.833198
# std       1.202199
# min       2.000000
# 25%       2.000000
# 50%       2.000000
# 75%       3.000000
# max      10.000000
# ...

# %% [markdown]
# # Q5
#
# Use the .head() and .tail() command - what does this do?
#
# head() displays the first N rows, tail() displays the last N rows.

# %%
for item in datasets.items():
  df = pd.DataFrame(item[1])
  print(f'{item[0]}:')
  print(df.head())
  print(df.tail())
# Out:
# https://raw.githubusercontent.com/data602sps/datasetspractice/main/salarydata.csv:
#         Sate  2018 Mean Annual Wage  Unnamed: 2
# 0    Alabama                 90,620         NaN
# 1      Alaska                99,180         NaN
# 2     Arizona                88,800         NaN
# 3    Arkansas                81,430         NaN
# 4  California                97,110         NaN
#             Sate  2018 Mean Annual Wage  Unnamed: 2
# 46       Virginia                91,700         NaN
# 47     Washington                85,930         NaN
# 48  West Virginia                89,420         NaN
# 49      Wisconsin                85,200         NaN
# 50        Wyomimg                87,510         NaN
# https://raw.githubusercontent.com/data602sps/datasetspractice/main/kobe.csv:
#     vs  game quarter  time                                        description  \
# 0  ORL     1       1  9:47            Kobe Bryant makes 4-foot two point shot
# ...

# %% [markdown]
# # Extra Credit
#
# 1. Choose one of your datasets and remove the header information. (Can delete
# the row in excel, etc..)
# 2. Import the data into your environment using pandas. Display the .head() of your
# data showing no header information.
# 3. Using pandas, update the dataset to include the header information. Display the
# updated data using .head().

# %%
ds = datasets['https://raw.githubusercontent.com/data602sps/datasetspractice/main/kobe.csv']
ds
# Out:
#       vs  game quarter     time  \
# 0    ORL     1       1     9:47
# 1    ORL     1       1     9:07
# 2    ORL     1       1     8:11
# 3    ORL     1       1     7:41
# 4    ORL     1       1     7:03
# ..   ...   ...     ...      ...
# 128  ORL     3       4     3:33
# 129  ORL     3       4     2:02
# 130  ORL     3       4  00:23.9
# 131  ORL     3       4  00:06.9
# 132  ORL     3       4  00:00.5
#
#                                            description basket
# 0              Kobe Bryant makes 4-foot two point shot      H
# 1                            Kobe Bryant misses jumper      M
# 2                     Kobe Bryant misses 7-foot jumper      M
# 3    Kobe Bryant makes 16-foot jumper (Derek Fisher...      H
# 4                      Kobe Bryant makes driving layup      H
# ..                                                 ...    ...
# 128                        Bryant Layup Shot: Missed        M
# 129                          Bryant 3pt Shot: Missed        M
# ...

# %%
# Make a copy of datadrame
ds_copy = ds.copy()

# %%
# Remove header from copy
ds_copy.columns = range(ds_copy.shape[1])
ds_copy
# Out:
#        0  1  2        3                                                  4  5
# 0    ORL  1  1     9:47            Kobe Bryant makes 4-foot two point shot  H
# 1    ORL  1  1     9:07                          Kobe Bryant misses jumper  M
# 2    ORL  1  1     8:11                   Kobe Bryant misses 7-foot jumper  M
# 3    ORL  1  1     7:41  Kobe Bryant makes 16-foot jumper (Derek Fisher...  H
# 4    ORL  1  1     7:03                    Kobe Bryant makes driving layup  H
# ..   ... .. ..      ...                                                ... ..
# 128  ORL  3  4     3:33                        Bryant Layup Shot: Missed    M
# 129  ORL  3  4     2:02                          Bryant 3pt Shot: Missed    M
# 130  ORL  3  4  00:23.9                          Bryant 3pt Shot: Missed    M
# 131  ORL  3  4  00:06.9                          Bryant 3pt Shot: Missed    M
# 132  ORL  3  4  00:00.5                 Bryant Layup Shot: Made (31 PTS)    H
#
# [133 rows x 6 columns]

# %%
# Add column headers back into copy
ds_copy.columns = ds.columns
ds_copy
# Out:
#       vs  game quarter     time  \
# 0    ORL     1       1     9:47
# 1    ORL     1       1     9:07
# 2    ORL     1       1     8:11
# 3    ORL     1       1     7:41
# 4    ORL     1       1     7:03
# ..   ...   ...     ...      ...
# 128  ORL     3       4     3:33
# 129  ORL     3       4     2:02
# 130  ORL     3       4  00:23.9
# 131  ORL     3       4  00:06.9
# 132  ORL     3       4  00:00.5
#
#                                            description basket
# 0              Kobe Bryant makes 4-foot two point shot      H
# 1                            Kobe Bryant misses jumper      M
# 2                     Kobe Bryant misses 7-foot jumper      M
# 3    Kobe Bryant makes 16-foot jumper (Derek Fisher...      H
# 4                      Kobe Bryant makes driving layup      H
# ..                                                 ...    ...
# 128                        Bryant Layup Shot: Missed        M
# 129                          Bryant 3pt Shot: Missed        M
# ...

# %% [markdown]
# # Extrac Credit
#
# 1. Import a “dirty” dataset from the internet into your environment. (Missing values, improper coding of columns, etc.)
#
# Loaded dataset contain a bad column of data (last column) and the name of the first colum in misspelt - sate instead of state
#
# 2. Clean or “tidy” the data when loading into python using pandas

# %%
ds = pd.read_csv('https://raw.githubusercontent.com/data602sps/datasetspractice/main/salarydata.csv')
ds
# Out:
#                    Sate  2018 Mean Annual Wage  Unnamed: 2
# 0               Alabama                 90,620         NaN
# 1                 Alaska                99,180         NaN
# 2                Arizona                88,800         NaN
# 3               Arkansas                81,430         NaN
# 4             California                97,110         NaN
# 5               Colorado                82,560         NaN
# 6            Connecticut                96,010         NaN
# 7               Delaware                93,880         NaN
# 8   District of Columbia                89,880         NaN
# 9                Florida                87,410         NaN
# 10               Georgia                86,320         NaN
# 11                Hawaii                90,540         NaN
# 12                 Idaho                77,700         NaN
# 13              IIIinois                90,690         NaN
# 14               lndiana                83,680         NaN
# ...

# %%
ds = pd.read_csv('https://raw.githubusercontent.com/data602sps/datasetspractice/main/salarydata.csv', header = 0, names=['State', '2018 Mean Annual Wage'], usecols=[0, 1])
ds
# Out:
#                    State 2018 Mean Annual Wage
# 0               Alabama                 90,620
# 1                 Alaska                99,180
# 2                Arizona                88,800
# 3               Arkansas                81,430
# 4             California                97,110
# 5               Colorado                82,560
# 6            Connecticut                96,010
# 7               Delaware                93,880
# 8   District of Columbia                89,880
# 9                Florida                87,410
# 10               Georgia                86,320
# 11                Hawaii                90,540
# 12                 Idaho                77,700
# 13              IIIinois                90,690
# 14               lndiana                83,680
# 15                  lowa                82,960
# 16                Kansas                85,250
# 17              Kentucky                84,630
# 18             Louisiana                89,860
# ...
