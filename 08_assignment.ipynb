# %% [markdown]
# <a href="https://colab.research.google.com/github/himalayahall/DATA602/blob/main/08_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assignment 8**
#
# # **Weeks 10 & 11 - matplotlib & seaborn**
# * In this homework assignment, you will explore and analyze a public dataset of your choosing. Since this assignment is “open-ended” in nature, you are free to expand upon the requirements below. However, you must meet the minimum requirments as indicated in each section.
#
#
# * The preferred method for this analysis is in a .ipynb file. Feel free to use whichever platform of your choosing.
#
#
# ### **Some data examples:**
# •	https://www.data.gov/
#
# •	https://opendata.cityofnewyork.us/
#
# •	https://datasetsearch.research.google.com/
#
# •	https://archive.ics.uci.edu/ml/index.php
#
# ### **Resources:**
#
# •	https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html
#
# •	https://www.oreilly.com/library/view/python-data-science/9781491912126/ch04.html
#
# •	https://www.data-to-viz.com/
#
#
#
# ### **Headings or comments**
# **You are required to make use of comments, or headings for each section.  You must explain what your code is doing, and the results of running your code.**  Act as if you were giving this assignment to your manager - you must include clear and descriptive information for each section.
#
# ### **You may work as a group or indivdually on this assignment.**

# %% [markdown]
# # Introduction
#
# Dataset for [Mortality rate](https://data.worldbank.org/indicator/SP.DYN.IMRT.IN), infant (per 1,000 live births). Infant mortality is of worldwide concern, and it is important to track this metric for trends over time.

# %% [markdown]
# ______________
# # Data Exploration
# Import your dataset into your .ipynb, create dataframes, and explore your data.
#
# Include:
#
# * Summary statistics means, medians, quartiles,
# * Missing value information
# * Any other relevant information about the dataset.

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/himalayahall/DATA602/main/API_SP.DYN.IMRT.IN_DS2_en_csv_v2_5358299.csv")
df
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                      Indicator Name  Indicator Code   1960  \
# 0    Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN    NaN
# 1    Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN    NaN
# 2    Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN    NaN
# 3    Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN    NaN
# 4    Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN    NaN
# ..                                              ...             ...    ...
# 261  Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN    NaN
# 262  Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN    NaN
# 263  Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN    NaN
# 264  Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN  121.5
# 265  Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN   92.8
#
#       1961   1962   1963   1964   1965  ...       2013       2014       2015  \
# 0      NaN    NaN    NaN    NaN    NaN  ...        NaN        NaN        NaN
# 1      NaN    NaN    NaN    NaN    NaN  ...  52.421631  50.858298  49.416164
# 2      NaN    NaN  228.9  225.1  221.2  ...  57.200000  55.000000  53.000000
# 3      NaN    NaN    NaN    NaN    NaN  ...  71.152846  69.988550  68.760967
# 4      NaN    NaN    NaN    NaN    NaN  ...  63.500000  60.500000  57.900000
# ..     ...    ...    ...    ...    ...  ...        ...        ...        ...
# 261    NaN    NaN    NaN    NaN    NaN  ...  14.700000  13.800000  13.000000
# 262    NaN    NaN  278.2  272.0  265.1  ...  45.300000  45.400000  46.200000
# 263    NaN    NaN    NaN    NaN    NaN  ...  31.000000  30.200000  29.400000
# 264  119.4  117.6  116.1  114.7  113.7  ...  48.100000  47.200000  47.200000
# 265   90.6   88.4   86.1   83.8   81.6  ...  45.200000  43.200000  42.100000
#
#           2016       2017       2018       2019       2020       2021  \
# 0          NaN        NaN        NaN        NaN        NaN        NaN
# 1    48.047765  46.638627  45.268284  44.081350  43.027778  42.004211
# 2    51.100000  49.400000  47.800000  46.300000  44.800000  43.400000
# 3    67.571981  66.373973  64.945255  63.556011  62.165177  60.749633
# 4    55.700000  53.800000  52.000000  50.400000  48.700000  47.200000
# ..         ...        ...        ...        ...        ...        ...
# 261  12.200000  11.500000  10.800000  10.100000   9.600000   9.100000
# 262  46.100000  46.000000  46.600000  46.500000  45.800000  46.700000
# 263  28.900000  28.300000  27.800000  27.300000  26.900000  26.400000
# 264  45.600000  44.200000  43.600000  42.400000  41.100000  40.200000
# 265  40.600000  39.500000  38.000000  37.100000  36.600000  35.700000
#
#      Unnamed: 66
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 261          NaN
# 262          NaN
# 263          NaN
# 264          NaN
# 265          NaN
#
# [266 rows x 67 columns]

# %% [markdown]
# Below are summary statistics for this dataset. Note - in general, all aggregated global statistical measures of infant mortality are decreasing over time. This is great news, but it remains to be seen whether this trend holds across ALL countries. Also the rate at which infant mortality is coming down is salient.

# %%
df.describe()
# Out:
#              1960        1961        1962        1963        1964        1965  \
# count  117.000000  118.000000  119.000000  124.000000  128.000000  130.000000
# mean    98.122222   95.738983   93.710924   95.325806   94.282031   92.486154
# std     53.774106   53.211092   52.961770   57.336445   57.066779   56.889990
# min     16.300000   16.000000   15.600000   15.000000   14.300000   13.700000
# 25%     56.600000   54.875000   53.600000   51.800000   50.100000   48.850000
# 50%    101.400000   96.700000   95.100000   91.900000   88.900000   84.250000
# 75%    133.000000  130.450000  129.100000  130.250000  132.425000  131.100000
# max    220.400000  217.300000  214.300000  278.200000  272.000000  265.100000
#
#              1966        1967        1968        1969  ...        2013  \
# count  132.000000  136.000000  141.000000  146.000000  ...  244.000000
# mean    91.339394   88.598529   86.597163   84.663014  ...   25.795737
# std     56.726839   55.549660   55.143675   53.814710  ...   21.893360
# min     13.100000   12.600000   12.100000   11.700000  ...    1.200000
# 25%     48.175000   46.350000   43.300000   41.825000  ...    8.075000
# 50%     82.000000   78.150000   75.800000   73.600000  ...   18.050000
# 75%    129.525000  128.550000  127.200000  126.100000  ...   40.367750
# max    257.400000  249.000000  240.100000  231.100000  ...   98.000000
#
#              2014        2015        2016        2017        2018        2019  \
# count  244.000000  244.000000  244.000000  244.000000  244.000000  244.000000
# mean    25.101853   24.422290   23.785183   23.124049   22.525922   21.975127
# std     21.415608   20.935936   20.418155   19.977791   19.517414   19.071802
# min      1.100000    1.100000    1.100000    1.100000    1.000000    1.000000
# 25%      7.750000    7.375000    7.075000    6.750000    6.300000    5.975167
# 50%     17.300000   16.603220   16.038613   15.446060   14.833309   14.800000
# 75%     39.200000   37.925000   36.925000   35.775000   34.723224   33.407642
# max     96.000000   95.500000   90.100000   87.600000   85.200000   82.800000
#
#              2020        2021  Unnamed: 66
# count  244.000000  244.000000          0.0
# mean    21.402941   20.864509          NaN
# std     18.654596   18.234922          NaN
# min      1.000000    1.000000          NaN
# 25%      5.575000    5.400000          NaN
# 50%     14.650000   14.285545          NaN
# 75%     32.100000   31.400000          NaN
# max     80.500000   78.300000          NaN
#
# [8 rows x 63 columns]

# %% [markdown]
# # Data Wrangling
#
# The dataset is not in [tidy format](https://cran.r-project.org/web/packages/tidyr/vignettes/tidy-data.html). Notice,  each year is a column (variable). We will tidy the dataset as follows:
#
# - create a new column **Year**
# - **melt** (i.e. pivot longer) the dataframe so that the year **columns** become **observations** in the **Year** column
#
# First, to make it easier to apply the **melt** transformation we create a list of year column names

# %%
value_vars = [str(d) for d in range(1960, 2021)]

# %% [markdown]
# Now, we can apply the **melt** transformation using value_vars as the source of values. We set the name of the resulting variable **Year**, and the value variable **Mortality**.

# %%
df_long = pd.melt(df, id_vars = 'Country Name', value_vars=value_vars, var_name = 'Year', value_name = 'Mortality')
df_long.dtypes
# Out:
# Country Name     object
# Year             object
# Mortality       float64
# dtype: object

# %% [markdown]
# Next, drops **NAs** and change **Year** and **Mortality** to integer.

# %%
df_long.dropna(inplace=True)
df_long = df_long.astype({'Year' : int, 'Mortality' : int})
# df_long.set_index(['Country Name', 'Year'], inplace=True)
df_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12352 entries, 8 to 16225
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  12352 non-null  object
#  1   Year          12352 non-null  int64
#  2   Mortality     12352 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 386.0+ KB

# %% [markdown]
# Create utility function to extract data for a specific country.

# %%
from typing import List

def normalize_country_name(country : str):
  return country.lower().capitalize()

def create_country_df(countries : List[str]):
    '''
        Create a dataframe for named countries
    '''
    normalized_names = [normalize_country_name(c) for c in countries]
    t = df_long.loc[df_long['Country Name'].isin(normalized_names)]
    return t

# %% [markdown]
# Select countries of interest

# %%
countries_of_interest = [normalize_country_name(c) for c in ['afghanistan', 'germany', 'japan', 'india', 'china', 'kenya', 'pakistan', 'brazil', 'australia', 'angola']]
countries_of_interest
# Out:
# ['Afghanistan',
#  'Germany',
#  'Japan',
#  'India',
#  'China',
#  'Kenya',
#  'Pakistan',
#  'Brazil',
#  'Australia',
#  'Angola']

# %% [markdown]
# # Visualizations - Part 1
#
# Using matplotlib, create two or more plots that incorporate at least 5 of the following properties:
#
# Using matplotlib, create ***two or more plots*** that incorporate at least **5** of the following properties:
#
# Note: these properties vary based on your data.  The goal is to practice creating visualizations and modifying its properties.
#
# *   Use and change a legend position
# *   Change a legend font size
# *   Place a legend outside of the plot
# *   Create a single legend for all subplots
# *   Change the title and x/y labels
# *   Change the marker, line colors, and line width
# *   Add annotations
# *   Modify Axis Text Ticks/Labels
# *   Change size of axis Labels
# *   Your own choice not included above
#
#
# Plots that you can create **include**:
#
# *   Scatter Plot
# *   Bar plot
# *   Line Chart
# *   Multi Plots (e.g. using .subplot()
# *   Histogram
#
# You can add another plot not listed here if it works better for your data.  This is not a complete list of plots to create.

# %%
from matplotlib import pyplot as plt

# %%
def matplotlib_draw_lineplots(countries : List[str]):
    '''
        Display lineplot for selected countries
    '''
    df = create_country_df(countries)
    normalized_names = [normalize_country_name(c) for c in countries]
    
    ax = plt.axes()

    for clc in normalized_names:
        ax.plot(df[df['Country Name'] == clc]['Year'], df[df['Country Name'] == clc]['Mortality'], label=clc)

    plt.title('Global Infant Mortality')
    plt.style.use('fivethirtyeight')

    # Label color, font size
    plt.xlabel('Year', color = 'Blue', fontsize=10)
    plt.ylabel('Mortality rate, infant (per 1,000 live births)', color='Blue', fontsize=8)

    # Legend position, title, and font size
    plt.legend(loc='upper right', title='Countries', fontsize=8)
    plt.show()


def matplotlib_draw_boxplots(countries : str):
    '''
       Display boxplots for selected countries
   '''
    df = create_country_df(countries)
    normalized_names = [normalize_country_name(c) for c in countries]
    dict = {}
    for country in normalized_names:
        dict[country] = df[df['Country Name'] == country]['Mortality']

    merged = pd.DataFrame(dict)

    ax = plt.axes()
    
    # Settings

    labels = list(df)
    ax.boxplot(dict.values(), labels=dict.keys(), showmeans = True)

    plt.rc('xtick', labelsize=4)

    ax.set_title('Global Infant Mortality')
    ax.set_xlabel('Country', color = 'Blue', fontsize=10)
    ax.set_ylabel('Mortality rate, infant (per 1,000 live births)', color = 'Blue', fontsize=10)
    plt.show()

# %%
list(df_long)
# Out:
# ['Country Name', 'Year', 'Mortality']

# %%
matplotlib_draw_lineplots(countries_of_interest)

# %%
matplotlib_draw_boxplots(countries_of_interest)

# %% [markdown]
# # Part 2
#
# Recreate the visualizations above using the Seaborn library as best as possible.
#
# You are required to explain what each of your plots is representing. Plots without comments will not be accepted. In addition, please explain the properties you are showcasing.

# %% [markdown]
# # Part 3
#
# In a comment or text box, explain the differences between creating a plot in matplotlib and seaborn, based on your above plots

# %% [markdown]
# # Conclusions
#
# After exploring your dataset, provide a short summary of what you noticed from this dataset.
