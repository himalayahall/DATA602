# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Q1
#
# What will the following code display?
#
# `numbers = [1, 2, 3, 4, 5]`
#
# `print(numbers[1:-5])`
#
# Can you debug and fix the output? The code should return the entire list
#
# Answer:
#
# The problem will above code is with the start/end indices - start index is 1 (second element in list) and ending index is -5 (first element in list). It is the same as writing `numbers[1:0]` which will return the `[]` list.

# %%
numbers = [1, 2, 3, 4, 5]
numbers[1:0]
# Out:
# []

# %% [markdown]
# To print the entire list one just has to pass the list reference, without slicing, to `print`.

# %%
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# # Q2
#
# Design a program that asks the user to enter a store’s sales for each day of the
# week. The amounts should be stored in a list. Use a loop to calculate the total sales for
# the week and display the result.

# %%
# day names for prompting
day_names = ['monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday']

# weekly sales
week_sales = []

# ask for sales for each day of week
for day in day_names:
    sale = float(input(f'Please enter sale for {day}: '))
    print(f'> You entered sale: {sale}')
    week_sales.append(sale)
    
# use sum() to total weekly sales
print('Total weekly sales:', sum(week_sales))
# Out:
# Please enter sale for monday:  10
# > You entered sale: 10.0
# Please enter sale for tuesday:  20
# > You entered sale: 20.0
# Please enter sale for wednesday:  30
# > You entered sale: 30.0
# Please enter sale for thursday:  40
# > You entered sale: 40.0
# Please enter sale for friday:  50
# > You entered sale: 50.0
# Please enter sale for saturday:  60
# > You entered sale: 60.0
# Please enter sale for sunday:  70
# > You entered sale: 70.0
# Total weekly sales: 280.0

# %% [markdown]
# # Q3
#
# Create a list with at least 5 places you’d like to travel to. Make sure the list isn’t in
# alphabetical order
#
# - Print your list in its original order.
# - Use the sort() function to arrange your list in order and reprint your list.
# - Use the sort(reverse=True) and reprint your list.

# %%
bucket_list = ['oslo', 'auckland', 'austin', 'machu picchu', 'zagreb', 'rabat']
print(bucket_list)

bucket_list.sort()
print(bucket_list)

bucket_list.sort(reverse=True)
print(bucket_list)
# Out:
# ['oslo', 'auckland', 'austin', 'machu picchu', 'zagreb', 'rabat']
# ['auckland', 'austin', 'machu picchu', 'oslo', 'rabat', 'zagreb']
# ['zagreb', 'rabat', 'oslo', 'machu picchu', 'austin', 'auckland']

# %% [markdown]
# # Q4
#
# Write a program that creates a dictionary containing course numbers and the room
# numbers of the rooms where the courses meet. The program should also create a
# dictionary containing course numbers and the names of the instructors that teach each
# course. After that, the program should let the user enter a course number, then it should
# display the course’s room number, instructor, and meeting time.

# %%
# For simplicity course numbers are numbers (case-insensitive and easy to input)
course_room = {'602':'A7E', '607':'A7W', '606':'B8N', '605':'B8S'}
course_instructor = {'602':'John Glen', '607':'Richard Feynman', '606':'Albert Einstein', '605':'Ada Lovelace'}
course_time = {'602':'7 PM', '607':'6 PM', '606':'7 PM', '605':'6 PM'}

while True:
    course = input('Please enter course number (enter blank to exit): ')
    if course == '':
        print('> Goodbye')
        break
    print(f'> You entered course number: {course}')
    try:
        room = course_room[course]
        time = course_time[course]
        instructor = course_instructor[course]
        print(f'Course will be taught in room {room} at {time} by {instructor}')
    except:
        print(f'** Invalid course number {course}')
# Out:
# Please enter course number (enter blank to exit):  602
# > You entered course number: 602
# Course will be taught in room A7E at 7 PM by John Glen
# Please enter course number (enter blank to exit):  605
# > You entered course number: 605
# Course will be taught in room B8S at 6 PM by Ada Lovelace
# Please enter course number (enter blank to exit):  455
# > You entered course number: 455
# ** Invalid course number 455
# Please enter course number (enter blank to exit):
# > Goodbye

# %% [markdown]
# # Q5
#
# Write a program that keeps names and email addresses in a dictionary as
# key-value pairs. The program should then demonstrate the four options:
#
# - look up a person’s email address,
# - add a new name and email address,
# - change an existing email address, and
# - delete an existing name and email address.

# %%
import re

regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'

contacts = {}

# prompt for contact name
def contact_name():
    name = input('Please enter contact name: ')
    print(f'> You entered name: {choice}')
    return name
 
def valid_email(email):
    # pass the regular expression
    # and the string into the fullmatch() method
    return re.fullmatch(regex, email)


# Add or update contact
def upsert_contact(is_updating):
    name = contact_name()
    if is_updating == True and contacts.get(name) is None:
        print(f'** Name {name} not found')
    else:
        email = input('Enter email address: ')
        print(f'> You entered email: {email}')
        if valid_email(email):
            contacts[name] = email
        else:
            print(f'** Invalid email')


# add contact
def add_contact():
    upsert_contact(False)


# update contact
def update_contact():
    upsert_contact(True)


# delete contact
def delete_contact():
    name = contact_name()
    if contacts.get(name) is None:
        print(f'** Name {name} not found')
    else:
        del (contacts[name])


# lookup email address
def lookup_email():
    name = contact_name()
    email = contacts.get(name)
    if email is None:
        print(f'** Name {name} not found')
    else:
        print(f'Email address for {name}: ', email)


# print menu
def print_menu():
    print('1. Lookup email address')
    print('2. Add contact')
    print('3. Update contact')
    print('4. Delete contact')
    print('0. Exit')


# driver loop
while True:
    print_menu()
    choice = int(input('Please make your selection: '))
    print(f'> You selected: {choice}')
    if choice == 1:
        lookup_email()
    elif choice == 2:
        add_contact()
    elif choice == 3:
        update_contact()
    elif choice == 4:
        delete_contact()
    elif choice == 0:
        break
    else:
        print('Invalid selection')
# Out:
# 1. Lookup email address
# 2. Add contact
# 3. Update contact
# 4. Delete contact
# 0. Exit
# Please make your selection:  2
# > You selected: 2
# Please enter contact name:  jawaid
# > You entered name: 2
# Enter email address:  foo@hotmail.com
# > You entered email: foo@hotmail.com
# 1. Lookup email address
# 2. Add contact
# 3. Update contact
# 4. Delete contact
# 0. Exit
# Please make your selection:  2
# > You selected: 2
# Please enter contact name:  frank
# > You entered name: 2
# Enter email address:  bar@gmail.com
# > You entered email: bar@gmail.com
# 1. Lookup email address
# 2. Add contact
# 3. Update contact
# 4. Delete contact
# 0. Exit
# Please make your selection:  2
# > You selected: 2
# Please enter contact name:  joe
# > You entered name: 2
# Enter email address:  kdkf@
# > You entered email: kdkf@
# ** Invalid email
# 1. Lookup email address
# 2. Add contact
# 3. Update contact
# 4. Delete contact
# 0. Exit
# Please make your selection:  1
# > You selected: 1
# ...
